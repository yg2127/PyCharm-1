# %%
import requests
import pprint
import json

# %%
url = "https://openapi.gg.go.kr/UndergroundWaterConstruct?KEY=4ada485c7cf2422f965f5e897ff71d0a&pIndex=1&pSize=50&SIGUN_CD=41310"

# %%
response = requests.get(url)
contents = response.text

print(contents)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
#
# <UndergroundWaterConstruct>
#   <head>
#     <list_total_count>10</list_total_count>
#     <RESULT>
#       <CODE>INFO-000</CODE>
#       <MESSAGE>정상 처리되었습니다.</MESSAGE>
#     </RESULT>
#     <api_version>1.0v</api_version>
#   </head>
#   <row>
#     <SIGUN_CD>41310</SIGUN_CD>
#     <SIGUN_NM>구리시</SIGUN_NM>
#     <BIZPLC_NM>(주)대현지오텍</BIZPLC_NM>
#     <LICENSG_DE>19980205</LICENSG_DE>
#     <LICENSG_CANCL_DE></LICENSG_CANCL_DE>
#     <BSN_STATE_NM>취소정지업체</BSN_STATE_NM>
#     <BSN_STATE_DIV_CD>2</BSN_STATE_DIV_CD>
#     <CLSBIZ_DE></CLSBIZ_DE>
#     <CAPTL_AMT>150000000</CAPTL_AMT>
#     <LOCPLC_FACLT_TELNO></LOCPLC_FACLT_TELNO>
#     <LOCPLC_AR_INFO></LOCPLC_AR_INFO>
#     <ROADNM_ZIP_CD></ROADNM_ZIP_CD>
#     <REFINE_LOTNO_ADDR>경기도 구리시 인창동 670-9번지 세신리빙프라자 904호</REFINE_LOTNO_ADDR>
#     <REFINE_ROADNM_ADDR>경기도 구리시 건원대로34번길 9, 904호 (인창동,세신리빙프라자)</REFINE_ROADNM_ADDR>
#     <REFINE_ZIP_CD>11921</REFINE_ZIP_CD>
# ...

# %%
import pandas as pd
from pandas.io.json import json_normalize
